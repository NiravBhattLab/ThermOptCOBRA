# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.io import loadmat

# %%
data = loadmat('Results_MostCommonTICsBIGG.mat')
unique_tics = [data['unique_tics'][i][0][0] for i in range(len(data['unique_tics']))]
unique_tics = [i.replace(' ','\n') for i in unique_tics]
counts = [data['count'][i][0] for i in range(len(data['count']))]

# %%
# bar plot on top 10 TICs
top_n = 18
fig,ax =plt.subplots(1,1,figsize=(top_n,5))
ax.bar(unique_tics[:top_n],counts[:top_n],color='tab:blue')
for i in range(top_n):
  ax.text(i, counts[i]+1, counts[i], ha='center', va='bottom',fontsize=9,fontweight='bold')

# ax.text(list(range(top_n)), np.array(counts[:top_n])+2, counts[:top_n], ha='center', va='bottom',fontsize=6,fontweight='bold')
ax.set_xticklabels(ax.get_xticklabels(),fontsize=8,fontweight='bold')
ax.set_yticklabels(ax.get_yticklabels(),fontweight='bold',fontsize=9)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_ylabel("Number of models",fontweight='bold',fontsize=12)
ax.set_xlabel("TICs",fontweight='bold',fontsize=12)
plt.savefig('CommonTICsBIGG.pdf',bbox_inches='tight')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_35824\496779942.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),fontsize=8,fontweight='bold')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_35824\496779942.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(),fontweight='bold',fontsize=9)

# %%
data = loadmat('Results_MostCommonTICsAGORA.mat')
unique_tics = [data['unique_tics'][i][0][0] for i in range(len(data['unique_tics']))]
unique_tics = [i.replace(' ','\n') for i in unique_tics]
counts = [data['count'][i][0] for i in range(len(data['count']))]

# %%
# bar plot on top 10 TICs
top_n = 20
fig,ax =plt.subplots(1,1,figsize=(top_n,5))
ax.bar(unique_tics[:top_n],counts[:top_n],color='tab:blue')
for i in range(top_n):
  ax.text(i, counts[i]+1, counts[i], ha='center', va='bottom',fontsize=9,fontweight='bold')

# ax.text(list(range(top_n)), np.array(counts[:top_n])+2, counts[:top_n], ha='center', va='bottom',fontsize=6,fontweight='bold')
ax.set_xticklabels(ax.get_xticklabels(),fontsize=9,fontweight='bold')
ax.set_yticklabels(ax.get_yticklabels(),fontweight='bold',fontsize=9)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_ylabel("Number of models",fontweight='bold',fontsize=12)
ax.set_xlabel("TICs",fontweight='bold',fontsize=12)
plt.savefig('CommonTICsAGORA.pdf',bbox_inches='tight')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_35824\2682374136.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),fontsize=9,fontweight='bold')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_35824\2682374136.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(),fontweight='bold',fontsize=9)
